# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
import scipy as sp
import scipy.stats as st
import pickle as pkl
import csv as csv
print "Modules Imported!"
# Out:
# Modules Imported!

# %%
x = np.linspace(0,6,10001)

# y = 1./np.sqrt(1+(x/5.-20./x)**2)
# plt.plot(x,y,'b',label = '$|H(\omega)|$')
# plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
# plt.title('Frequency Response when R=1$\Omega$')
# plt.xlabel('$\omega$')
# plt.ylabel('$|H(\omega)|$')
# # plt.ylim(0, 20)
# plt.legend()
# plt.show()

# y = 25.*x**2/(x**4-175*x**2+10000)
# # plt.axhline(y=1, color='b', linestyle='-',label = '$Re\{H(\omega)\}$')
# plt.plot(x,y,'b',label = '$Re\{H(\omega)\}$')
# plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
# plt.title('$Re\{H(\omega)\}$')
# plt.xlabel('$\omega$')
# plt.ylabel('$Re\{H(\omega)\}$')
# plt.xlim(-55, 55)
# # plt.ylim(0, 20)
# plt.legend()
# plt.show()


# # y = 1./np.sqrt((x/5.-20./x)**2)
# y = -5*x*(x**2-100)/(x**4-175*x**2+10000)
# plt.plot(x,y,'b',label = '$Im\{H(\omega)\}$')
# plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
# plt.title('$Im\{H(\omega)\}$')
# plt.xlabel('$\omega$')
# plt.ylabel('$Im\{H(\omega)\}$')
# # plt.ylim(0, 20)
# plt.legend()
# plt.show()

# y = 1./np.sqrt((10)**2+(x/5.-20./x)**2)
# plt.plot(x,y,'b',label = '$|H(\omega)|$')
# plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
# plt.title('Frequency Response when R=10$\Omega$')
# plt.xlabel('$\omega$')
# plt.ylabel('$|H(\omega)|$')
# # plt.ylim(0, 20)
# plt.legend()
# plt.show()

# y = 1./np.sqrt((0.1)**2+(x/5.-20./x)**2)
# plt.plot(x,y,'b',label = '$|H(\omega)|$')
# plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
# plt.title('Frequency Response when R=0.1$\Omega$')
# plt.xlabel('$\omega$')
# plt.ylabel('$|H(\omega)|$')
# # plt.ylim(0, 20)
# plt.legend()
# plt.show()

# y = 1./np.sqrt(1+(0.2*x-1./(0.05*x))**2)
# plt.plot(x,y,'b',label = '$|H(\omega)|$')
# plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
# plt.title('Frequency Response when R=0.1$\Omega$')
# plt.xlabel('$\omega$')
# plt.ylabel('$|H(\omega)|$')
# plt.ylim(0, 20)
# plt.legend()
# plt.show()

# print np.absolute(np.sinc(2*np.pi*4*0.5/2))
# 2*np.pi*x*0.5/2
a = np.sinc(0.5*x)
b = np.absolute(a)
c = np.log10(b)
y = 20*c
plt.plot(x,y,'b',label = '$|H(\omega)|$')
# plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
plt.title('Frequency Response when R=0.1$\Omega$')
plt.xlabel('$\omega$')
plt.ylabel('$|H(\omega)|$')
plt.ylim(-30, 0)
plt.legend()
plt.show()

# for i in range (480,500,1):
#     k = i/100.
#     print k
print 20*np.log10(np.absolute(np.sinc(0.5*2.86)))
print np.absolute(np.sinc(0.5*2.86))
# Out:
# -13.2614626567
# 0.217233533858

# %%
x = np.linspace(0,20,1001)

y = np.sqrt((4.*x**4+x**2))/((x**2+4.))
plt.plot(x,y,'b',label = '$|H(\omega)|$')
# plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
plt.title('$|H(\omega)|$ vs. Frequency')
plt.xlabel('$\omega$')
plt.ylabel('$|H(\omega)|$')
# plt.ylim(0, 5)
plt.legend()
plt.show()

# x1= np.linspace(0, 1.9, 1000, endpoint=False)
# x2= np.linspace(2.1, 20, 1000, endpoint=True)

x = np.linspace(-20,20,1001)
# x = np.append(x1,x2)
y = np.arctan((7.*x**2+4.)/(2*x**3-4.*x))
plt.plot(x,y,'b',label = '$\measuredangle H(\omega)$')
# plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
plt.title('$\measuredangle H(\omega)$ vs. Frequency')
plt.xlabel('$\omega$')
plt.ylabel('$\measuredangle H(\omega)$')
# plt.ylim(0, 5)
# plt.xlim(1.9,2.1)
plt.legend()
plt.show()

# x = np.append(x1,x2)
y = np.arctan((-1.)/(x))-np.arctan((4.*x)/(4.-x**2))
plt.plot(x,y,'b',label = '$\measuredangle H(\omega)$')
# plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
plt.title('$\measuredangle H(\omega)$ vs. Frequency')
plt.xlabel('$\omega$')
plt.ylabel('$\measuredangle H(\omega)$')
# plt.ylim(0, 5)
# plt.xlim(1.9,2.1)
plt.legend()
plt.show()
# Out:
# /Users/nickelliang/Virtualenvs/ECE314-py2/lib/python2.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in divide
# /Users/nickelliang/Virtualenvs/ECE314-py2/lib/python2.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: divide by zero encountered in divide

# %%
x = np.linspace(0,20,1001)

y = np.sqrt((x)**2)/((x**2+1.))
plt.plot(x,y,'b',label = '$|H(\omega)|$')
# plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
plt.title('$|H(\omega)|$ vs. Frequency')
plt.xlabel('$\omega$')
plt.ylabel('$|H(\omega)|$')
# plt.ylim(0, 5)
plt.legend()
plt.show()

# x1= np.linspace(0, 1.9, 1000, endpoint=False)
# x2= np.linspace(2.1, 20, 1000, endpoint=True)

x = np.linspace(0,20,1001)
# x = np.append(x1,x2)
y = -np.arctan((x**2-1.)/(2.*x))
plt.plot(x,y,'b',label = '$\measuredangle H(\omega)$')
# plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
plt.title('$\measuredangle H(\omega)$ vs. Frequency')
plt.xlabel('$\omega$')
plt.ylabel('$\measuredangle H(\omega)$')
# plt.ylim(0, 5)
# plt.xlim(1.9,2.1)
plt.legend()
plt.show()

# # x = np.append(x1,x2)
# y = (np.pi/2) - np.arctan((2.*x)/(1.-x**2))
# plt.plot(x,y,'b',label = '$\measuredangle H(\omega)$')
# # plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
# plt.title('$\measuredangle H(\omega)$ vs. Frequency')
# plt.xlabel('$\omega$')
# plt.ylabel('$\measuredangle H(\omega)$')
# # plt.ylim(0, 5)
# # plt.xlim(1.9,2.1)
# plt.legend()
# plt.show()
# Out:
# /Users/nickelliang/Virtualenvs/ECE314-py2/lib/python2.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in divide

# %%
up = np.pi*4/3

x = np.linspace(0,up,1001)


y = 8*np.cos(3*x)
plt.plot(x,y,'b',label = '$f(t)$')
# plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
plt.title('$f(t)$ vs. Frequency')
plt.xlabel('$\omega$')
plt.ylabel('$f(t)$')
# plt.ylim(0, 5)
plt.legend()
plt.show()

# n=3
# up = np.pi*2/n
# print up
# x = np.linspace(0,up,1001)
# y = np.sqrt(np.sin(n*x)**2)
# z = np.sin(n*x)
# plt.plot(x,y,'b',label = '$f(t)$')
# plt.plot(x,z,'r')
# # plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
# plt.title('$f(t)$ vs. Frequency')
# plt.xlabel('$\omega$')
# plt.ylabel('$f(t)$')
# # plt.ylim(0, 5)
# plt.legend()
# plt.show()
