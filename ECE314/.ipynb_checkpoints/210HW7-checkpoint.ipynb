# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
import scipy as sp
import scipy.stats as st
import pickle as pkl
import csv as csv
print "Modules Imported!"
# Out:
# Modules Imported!

# %%
x = np.linspace(-50,50,1000)

y = np.sqrt(1+(x/5.-20./x)**2)
plt.plot(x,y,'b',label = '$|H(\omega)|$')
plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
plt.title('Frequency Response when R=1$\Omega$')
plt.xlabel('$\omega$')
plt.ylabel('$|H(\omega)|$')
plt.ylim(0, 20)
plt.legend()
plt.show()

# # y = np.sqrt((1)**2)
plt.axhline(y=1, color='b', linestyle='-',label = '$Re\{H(\omega)\}$')
plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
plt.title('$Re\{H(\omega)\}$')
plt.xlabel('$\omega$')
plt.ylabel('$Re\{H(\omega)\}$')
plt.xlim(-55, 55)
plt.ylim(0, 20)
plt.legend()
plt.show()


y = np.sqrt((x/5.-20./x)**2)
plt.plot(x,y,'b',label = '$Im\{H(\omega)\}$')
plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
plt.title('$Im\{H(\omega)\}$')
plt.xlabel('$\omega$')
plt.ylabel('$Im\{H(\omega)\}$')
plt.ylim(0, 20)
plt.legend()
plt.show()

y = np.sqrt((10)**2+(x/5.-20./x)**2)
plt.plot(x,y,'b',label = '$|H(\omega)|$')
plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
plt.title('Frequency Response when R=10$\Omega$')
plt.xlabel('$\omega$')
plt.ylabel('$|H(\omega)|$')
plt.ylim(0, 20)
plt.legend()
plt.show()

y = np.sqrt((0.1)**2+(x/5.-20./x)**2)
plt.plot(x,y,'b',label = '$|H(\omega)|$')
plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
plt.title('Frequency Response when R=0.1$\Omega$')
plt.xlabel('$\omega$')
plt.ylabel('$|H(\omega)|$')
plt.ylim(0, 20)
plt.legend()
plt.show()

# %%
x = np.linspace(0,20,1001)

y = np.sqrt((2.*x**4+7.*x**2-4.)**2)/((x**2+4.)**2)
plt.plot(x,y,'b',label = '$|H(\omega)|$')
# plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
plt.title('$|H(\omega)|$ vs. Frequency')
plt.xlabel('$\omega$')
plt.ylabel('$|H(\omega)|$')
# plt.ylim(0, 5)
plt.legend()
plt.show()

# x1= np.linspace(0, 1.9, 1000, endpoint=False)
# x2= np.linspace(2.1, 20, 1000, endpoint=True)

# x = np.append(x1,x2)
y = np.arctan((4*x)/(x**2-4))
plt.plot(x,y,'b',label = '$\measuredangle H(\omega)$')
# plt.axvline(x=10, color='red',label = '$\omega=10$', linestyle='--')
plt.title('$\measuredangle H(\omega)$ vs. Frequency')
plt.xlabel('$\omega$')
plt.ylabel('$\measuredangle H(\omega)$')
# plt.ylim(0, 5)
# plt.xlim(1.9,2.1)
plt.legend()
plt.show()
# Out:
# /Users/nickelliang/Virtualenvs/ECE314-py2/lib/python2.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in divide
